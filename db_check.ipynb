# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect('ioc_cache.db')

# %%
query = "SELECT * FROM misp_iocs;"

# %%
df = pd.read_sql_query(query, conn)

# %%
df.head()
# Out:
#    id  event_id                            event_uuid           event_info  \
# 0   1      1837  f6927e55-0551-4a96-ab24-34f41d2dcf08  Malware Bazaar feed
# 1   2      1837  f6927e55-0551-4a96-ab24-34f41d2dcf08  Malware Bazaar feed
# 2   3      1837  f6927e55-0551-4a96-ab24-34f41d2dcf08  Malware Bazaar feed
# 3   4      1837  f6927e55-0551-4a96-ab24-34f41d2dcf08  Malware Bazaar feed
# 4   5      1837  f6927e55-0551-4a96-ab24-34f41d2dcf08  Malware Bazaar feed
#
#    event_date      event_timestamp  attribute_id attribute_type  \
# 0  2025-06-18  2025-06-18 09:38:24       1106306            md5
# 1  2025-06-18  2025-06-18 09:38:24       1106307            md5
# 2  2025-06-18  2025-06-18 09:38:24       1106308            md5
# 3  2025-06-18  2025-06-18 09:38:24       1106309            md5
# 4  2025-06-18  2025-06-18 09:38:24       1106310            md5
#
#   attribute_category                   attribute_value  attribute_timestamp  \
# ...
